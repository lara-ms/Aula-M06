# %% [markdown]
# <a href="https://colab.research.google.com/github/lara-ms/Aula-M06/blob/main/ATV_3_Lara_Siecola.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Nome: Lara Moreira Siécola
# ## Matrícula: 2365

# %% [markdown]
# # Atividade 6 — Refinamento de Raízes: Método de Newton-Raphson
# ## Contexto: Nós de uma Função de Onda Quântica

# %% [markdown]
# Na disciplina de F04 (Física Moderna e Quântica), os **nós de uma função de onda** representam posições nas quais a amplitude de probabilidade é nula. Em um modelo simplificado relacionado ao oscilador harmônico quântico, a parte polinomial de uma função de onda pode ser representada por:
#
# $$\psi(x)=4x^3-6x$$
#
# Para aplicar o método de Newton-Raphson, utiliza-se sua derivada:
#
# $${\psi}'(x)=12x^2-6$$
#
# Nesta atividade, o objetivo é localizar numericamente os valores de $x$ para os quais $\psi(x)=0$ e analisar como o chute inicial e a tolerância influenciam a convergência.

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return 4*x**3 - 6*x

def df(x):
    return 12*x**2 - 6

# %%
def newton_raphson(x0, tol=1e-9, max_iter=100):
    x = x0
    for i in range(max_iter):
        if abs(f(x)) < tol:
            return x, i
        if abs(df(x)) < 1e-12:
            raise ValueError("Derivada muito próxima de zero. Escolha outro chute inicial.")
        x = x - f(x)/df(x)
    return x, max_iter

# %% [markdown]
# ## Parte Prática
# 1. Plote $f(x)$ no intervalo $[-2;2]$, indicando com uma linha tracejada o eixo $y=0$ e identificando visualmente as possíveis raízes.

# %% [markdown]
# - Calculando as raízes:
#
# $$4x^3-6x = 0$$
# - Aqui é possível ja identificar que 0 é uma raiz, agoras as outras são calculadas abaixo:
#
# $$4x^3-6x = 0$$
# $$4x^3 = 6x$$
# $$4x^2 = 6$$
# $$x^2 = 6/4 = 3/2$$
# $$x = ± sqrt(3/2)$$
# $$x = ± 1.2247$$

# %%
# Indicando o intervalo
x = np.linspace(-2, 2)
y = f(x)

# Criando a figura
plt.figure(figsize=(8, 5))

# Plotando f(x)
plt.plot(x, y, color='blue')

# Indicando com linha tracejada o eixo y=0
plt.axhline(0, color='red', linestyle='--')

# Detalhes estéticos do gráfico
plt.title("Plotando f(x) e suas possíveis raízes")
plt.xlabel("x")
plt.ylabel(r"$\psi(x)$")
plt.grid(True, linestyle=':', alpha=1)

# Exibindo o gráfico
plt.show()

# %% [markdown]
# 2. Aplique o método de Newton-Raphson utilizando o chute inicial $x_0=1{,}8$. Apresente a raiz aproximada e o número de iterações.

# %%
# Chamando o metodo de newton-raphson
metodo_np = newton_raphson(1.8)

# Mostando o resultado do metodo
print("Raiz aproximada: ", metodo_np[0])
print("Número de iterações: ", metodo_np[1])
# Out:
# Raiz aproximada:  1.2247448713969942
# Número de iterações:  5

# %% [markdown]
# 3. Teste os chutes iniciais $(-2{,}0; -1{,}0; -0{,}4; 0{,}2; 0{,}8; 1{,}6)$ e compare a raiz encontrada e o número de iterações em cada caso.

# %%
# Caso 1 ----------------------------------------------------
# Chamando o metodo de newton-raphson
print("Caso 1 (-2.0):")
metodo_np = newton_raphson(-2.0)

# Mostando o resultado do metodo
print("Raiz:", metodo_np[0])
print("Número de iterações:", metodo_np[1])

# Caso 2 ----------------------------------------------------
# Chamando o metodo de newton-raphson
print("\nCaso 2 (-1.0):")
metodo_np = newton_raphson(-1.0)

# Mostando o resultado do metodo
print("Raiz:", metodo_np[0])
print("Número de iterações:", metodo_np[1])

# Caso 3 ----------------------------------------------------
# Chamando o metodo de newton-raphson
print("\nCaso 3 (-0.4):")
metodo_np = newton_raphson(-0.4)

# Mostando o resultado do metodo
print("Raiz:", metodo_np[0])
print("Número de iterações:", metodo_np[1])

# Caso 4 ----------------------------------------------------
# Chamando o metodo de newton-raphson
print("\nCaso 4 (0.2):")
metodo_np = newton_raphson(0.2)

# Mostando o resultado do metodo
print("Raiz:", metodo_np[0])
print("Número de iterações:", metodo_np[1])

# Caso 5 ----------------------------------------------------
# Chamando o metodo de newton-raphson
print("\nCaso 5 (0.8):")
metodo_np = newton_raphson(0.8)

# Mostando o resultado do metodo
print("Raiz:", metodo_np[0])
print("Número de iterações:", metodo_np[1])

# Caso 6 ----------------------------------------------------
# Chamando o metodo de newton-raphson
print("\nCaso 6 (1.6):")
metodo_np = newton_raphson(1.6)

# Mostando o resultado do metodo
print("Raiz:", metodo_np[0])
print("Número de iterações:", metodo_np[1])
# Out:
# Caso 1 (-2.0):
# Raiz: -1.224744871391589
# Número de iterações: 6
#
# Caso 2 (-1.0):
# Raiz: -1.2247448713915905
# Número de iterações: 5
#
# Caso 3 (-0.4):
# Raiz: -2.6469779601696886e-23
# Número de iterações: 4
#
# Caso 4 (0.2):
# Raiz: -1.1974928291807671e-17
# Número de iterações: 3
#
# Caso 5 (0.8):
# Raiz: 1.2247448713937779
# Número de iterações: 7
#
# Caso 6 (1.6):
# Raiz: 1.2247448713915896
# Número de iterações: 5

# %% [markdown]
# - Analisando as raízes resultantes é possível analisar que:
#
# - Chutes negativos mais a esquerda ($-2{,}0$ e $-1{,}0$) aproximam da raiz negativa (-1,2247); chutes próximos da origem ($-0{,}4$ e $0{,}2$) aproximam da raiz zero; e chutes positivos mais a direita ($1{,}6$) aproximam da raiz positiva (1,2247).

# %% [markdown]
# 4. Execute o método com as tolerâncias $10^{-3}$, $10^{-6}$ e $10^{-9}$, mantendo $x_0=1{,}8$. Analise o impacto da tolerância na aproximação da raiz e no número de iterações.

# %%
# Caso 1 ----------------------------------------------------
# Chamando o metodo de newton-raphson
metodo_np = newton_raphson(1.8, 1e-3)
print("Caso 1 (1e-3):")

# Mostando o resultado do metodo
print("Raiz aproximada: ", metodo_np[0])
print("Número de iterações: ", metodo_np[1])

# Caso 2 ----------------------------------------------------
# Chamando o metodo de newton-raphson
metodo_np = newton_raphson(1.8, 1e-6)
print("\nCaso 2 (1e-6):")

# Mostando o resultado do metodo
print("Raiz aproximada: ", metodo_np[0])
print("Número de iterações: ", metodo_np[1])

# Caso 3 ----------------------------------------------------
# Chamando o metodo de newton-raphson
metodo_np = newton_raphson(1.8, 1e-9)
print("\nCaso 3 (1e-9):")

# Mostando o resultado do metodo
print("Raiz aproximada: ", metodo_np[0])
print("Número de iterações: ", metodo_np[1])
# Out:
# Caso 1 (1e-3):
# Raiz aproximada:  1.2247469721871977
# Número de iterações:  4
#
# Caso 2 (1e-6):
# Raiz aproximada:  1.2247448713969942
# Número de iterações:  5
#
# Caso 3 (1e-9):
# Raiz aproximada:  1.2247448713969942
# Número de iterações:  5

# %% [markdown]
# - Analisando o impacto da tolerância no resultado das raízes e nas interações pode-se ter:
# - Quanto menor as a tolerância ($10^{-6}$ e $10^{-9}$) mais interações são necessárias e a raiz aproximada é mais próxima da raiz real, e pode-se perceber que chega um momento em que o resultado chega ao "limite", ou seja, se estabiliza.

# %% [markdown]
# ## Parte Teórica

# %% [markdown]
# 1. O que significa afirmar que o método de Newton-Raphson possui convergência quadrática próximo de uma raiz simples?
#
# **Resposta:**

# %% [markdown]
# Significa que quando a aproximação está próxima de uma raiz simples, o erro da próxima iteração é proporcional ao quadrado do erro da iteração atual. Uma vez que o erro de iteração é calculado por: $e = |x_{k+1} - x_k|$

# %% [markdown]
# 2. Como o método pode ser adaptado quando a derivada da função não está disponível analiticamente?
#
# **Resposta:**

# %% [markdown]
# Pode-se substituir a derivada (que seria a tangente) por uma aproximação numérica, usando o método da secante para achar a inclinação da função.

# %% [markdown]
# 3. Compare o método de Newton-Raphson com o método da bissecção, destacando as vantagens e limitações de cada um.
#
# **Resposta:**

# %% [markdown]
# O método de NEWTON-RAPHSON:
#
# **Vantagens**: Tem uma convergêcia mais rápida.
#
# **Limitações**: Pode divergir dependendo da escolha de $x_o$.
#
# O método da BISSECÇÃO:
#
# **Vantagens**: Fácil de aplicar, naão tem descontinuidade em um intervalo.
#
# **Limitações**: Tem uma convergência lenta, precisa de mais iterações até que seja atingida a precisão necessária.

# %% [markdown]
# 4. Quais problemas podem ocorrer durante a aplicação do método de Newton-Raphson? Cite pelo menos três e relacione um deles à possibilidade de a derivada ser igual ou muito próxima de zero.
#
# **Resposta:**

# %% [markdown]
# 1. Divisão por 0, uma vez que a fórmula é $x_{n+1} = x_n - (f(x_n)/f'(x_n))$, ou seja, fica dependendo de $f'(x_n)$ não ser 0 e caso seja próximo de 0 resultará em um salto bem distante do ponto atual.
#
# 2. Divergência no método, se caso a haja uma má escolha de $x_o$, se ele estiver longe da raiz real.
#
# 3. Lentidão no método, caso a função tenha raízes iguais o método fica lento pois a convergência se torna linear.
